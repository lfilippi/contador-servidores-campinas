# %% [markdown]
# # Monitor do número de servidores por secretaria
#
# Contabiliza mês a mês o número de funcionários contratados por secretaria. Basta digitar a secretaria desejada com as primeiras letras em caixa alta ("Educação", "Direitos da Pessoa com Deficiência e Cidadania" etc) e o programa retorna os dados.

# %%
# 1. Monitor do número de servidores por secretaria na Prefeitura de Campinas

import csv

busca_secretaria = ["Saúde"]
busca_print = busca_secretaria[0].title()

planilha = open('SalariosCampinas_janeiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em janeiro de 2017")

planilha = open('SalariosCampinas_fevereiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em fevereiro de 2017")

planilha = open('SalariosCampinas_marco2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em março de 2017")

planilha = open('SalariosCampinas_abril2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em abril de 2017")

planilha = open('SalariosCampinas_maio2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em maio de 2017")

planilha = open('SalariosCampinas_junho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em junho de 2017")

planilha = open('SalariosCampinas_julho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em julho de 2017")

planilha = open('SalariosCampinas_agosto2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em agosto de 2017")

planilha = open('SalariosCampinas_setembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em setembro de 2017")

planilha = open('SalariosCampinas_outubro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em novembro de 2017")

planilha = open('SalariosCampinas_dezembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em dezembro de 2017")
# Out:
# A Prefeitura de Campinas tem 5292 profissionais na folha salarial da Secretaria de Saúde em janeiro de 2017
# A Prefeitura de Campinas tem 5270 profissionais na folha salarial da Secretaria de Saúde em fevereiro de 2017
# A Prefeitura de Campinas tem 5244 profissionais na folha salarial da Secretaria de Saúde em março de 2017
# A Prefeitura de Campinas tem 5190 profissionais na folha salarial da Secretaria de Saúde em abril de 2017
# A Prefeitura de Campinas tem 5163 profissionais na folha salarial da Secretaria de Saúde em maio de 2017
# A Prefeitura de Campinas tem 5143 profissionais na folha salarial da Secretaria de Saúde em junho de 2017
# A Prefeitura de Campinas tem 5122 profissionais na folha salarial da Secretaria de Saúde em julho de 2017
# A Prefeitura de Campinas tem 5101 profissionais na folha salarial da Secretaria de Saúde em agosto de 2017
# A Prefeitura de Campinas tem 5070 profissionais na folha salarial da Secretaria de Saúde em setembro de 2017
# A Prefeitura de Campinas tem 5051 profissionais na folha salarial da Secretaria de Saúde em outubro de 2017
# A Prefeitura de Campinas tem 5022 profissionais na folha salarial da Secretaria de Saúde em novembro de 2017
# A Prefeitura de Campinas tem 5000 profissionais na folha salarial da Secretaria de Saúde em dezembro de 2017

# %% [markdown]
# # Monitor do número de servidores por cargo
#
# Contabiliza mês a mês o número de servidores contratados por cargo. Basta digitar o cargo a ser buscado todo em caixa alta ("GUARDA MUNICIPAL", "ASSISTENTE SOCIAL" etc) e o programa retorna os dados.

# %%
# 2. Monitor do número de servidores por cargo na Prefeitura de Campinas

import csv


busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_print = busca_cargo[0].title()

planilha = open('SalariosCampinas_janeiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de janeiro de 2017")

planilha = open('SalariosCampinas_fevereiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de fevereiro de 2017")

planilha = open('SalariosCampinas_marco2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de março de 2017")

planilha = open('SalariosCampinas_abril2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de abril de 2017")

planilha = open('SalariosCampinas_maio2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de maio de 2017")

planilha = open('SalariosCampinas_junho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de junho de 2017")

planilha = open('SalariosCampinas_julho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de julho de 2017")

planilha = open('SalariosCampinas_agosto2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de agosto de 2017")

planilha = open('SalariosCampinas_setembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de setembro de 2017")

planilha = open('SalariosCampinas_outubro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de novembro de 2017")

planilha = open('SalariosCampinas_dezembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de dezembro de 2017")
# Out:
# A Prefeitura de Campinas tem 2747 profissionais com o cargo de Professor na folha salarial de janeiro de 2017
# A Prefeitura de Campinas tem 2730 profissionais com o cargo de Professor na folha salarial de fevereiro de 2017
# A Prefeitura de Campinas tem 2711 profissionais com o cargo de Professor na folha salarial de março de 2017
# A Prefeitura de Campinas tem 2699 profissionais com o cargo de Professor na folha salarial de abril de 2017
# A Prefeitura de Campinas tem 2681 profissionais com o cargo de Professor na folha salarial de maio de 2017
# A Prefeitura de Campinas tem 2659 profissionais com o cargo de Professor na folha salarial de junho de 2017
# A Prefeitura de Campinas tem 2640 profissionais com o cargo de Professor na folha salarial de julho de 2017
# A Prefeitura de Campinas tem 2619 profissionais com o cargo de Professor na folha salarial de agosto de 2017
# A Prefeitura de Campinas tem 2602 profissionais com o cargo de Professor na folha salarial de setembro de 2017
# A Prefeitura de Campinas tem 2588 profissionais com o cargo de Professor na folha salarial de outubro de 2017
# A Prefeitura de Campinas tem 2573 profissionais com o cargo de Professor na folha salarial de novembro de 2017
# A Prefeitura de Campinas tem 2559 profissionais com o cargo de Professor na folha salarial de dezembro de 2017

# %% [markdown]
# # Monitor da folha de pagamento da prefeitura
#
# Contabiliza os valores pagos pela prefeitura aos funcionários. É possível fazer os cálculos para os tipos específicos de pagamentos. Para isso, a lista de todas as opções está abaixo. O número ao lado representa a posição da coluna na planilha, ou seja, para somar o Total Bruto, por exemplo, é preciso alterar o código para registro[16].
#
# Verbas Fixas [5]
# Cargo Comissão / Função Gratificada [6]
# Produtividade [7]
# Hora Extra [8]
# Sucumbência [9]
# Eventual [10]
# Adic.Crg./ Local/Jorn. [11]
# Salário Atraso [12]
# Prêmio Férias [13]
# Licença Prêmio [14]
# 13º Salário [15]
# Total Bruto [16]
# Deduções [17]
# Bruto c/ Deduções [18].

# %%
# 3. Monitor da folha de pagamento da prefeitura

import csv

total_calculo = 0
arquivo = open('SalariosCampinas_janeiro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_fevereiro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_marco2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_abril2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_maio2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_junho2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_julho2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_agosto2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_setembro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_outubro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_novembro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)

total_calculo = 0
arquivo = open('SalariosCampinas_dezembro2017.csv', encoding='utf8')
for registro in csv.reader(arquivo):
    item = registro[12]
    if item != 'Salário Atraso':
        total_calculo += int(item)
print(total_calculo)
# Out:
# 130359394
# 51812523
# 78933226
# 58677792
# 60562740
# 37570206
# 45287007
# 42286647
# 67689071
# 68719438
# 43221303
# 71850152
