# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-190b10e32e79> in <module>()
#       4 found = {}
#       5 count = 0
# ----> 6 for line in fin:
#       7     for word in words:
#       8         if word in line:
#
# NameError: name 'fin' is not defined

# %%
#Contador do número de profissionais médicos na Prefeitura de Campinas

import csv
planilha = open('SalariosCampinas_janeiro2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_fevereiro2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_marco2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_abril2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_maio2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_junho2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_julho2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_agosto2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_setembro2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_outubro2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")

planilha = open('SalariosCampinas_novembro2017.csv')
busca_cargo = ["MEDICO", "MÉDICO", "PSICOLOGO"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} médicos na folha salarial do mês")
# Out:
# A Prefeitura de Campinas tem 1715 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1704 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1692 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1693 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1682 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1671 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1665 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1653 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1641 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1638 médicos na folha salarial do mês
# A Prefeitura de Campinas tem 1631 médicos na folha salarial do mês

# %%
#Contador do número de professores na Prefeitura de Campinas

import csv
planilha = open('SalariosCampinas_janeiro2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de janeiro de 2017")

import csv
planilha = open('SalariosCampinas_fevereiro2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de fevereiro de 2017")

import csv
planilha = open('SalariosCampinas_marco2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de março de 2017")

import csv
planilha = open('SalariosCampinas_abril2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de abril de 2017")

import csv
planilha = open('SalariosCampinas_maio2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de maio de 2017")

import csv
planilha = open('SalariosCampinas_junho2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de junho de 2017")

import csv
planilha = open('SalariosCampinas_julho2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de julho de 2017")

import csv
planilha = open('SalariosCampinas_agosto2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de agosto de 2017")

import csv
planilha = open('SalariosCampinas_setembro2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de setembro de 2017")

import csv
planilha = open('SalariosCampinas_outubro2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv')
busca_cargo = ["PROFESSOR", "PROF.SUBST.TJE"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial de novembro de 2017")
# Out:
# A Prefeitura de Campinas tem 2747 profissionais na folha salarial de janeiro de 2017
# A Prefeitura de Campinas tem 2730 profissionais na folha salarial de fevereiro de 2017
# A Prefeitura de Campinas tem 2711 profissionais na folha salarial de março de 2017
# A Prefeitura de Campinas tem 2699 profissionais na folha salarial de abril de 2017
# A Prefeitura de Campinas tem 2681 profissionais na folha salarial de maio de 2017
# A Prefeitura de Campinas tem 2659 profissionais na folha salarial de junho de 2017
# A Prefeitura de Campinas tem 2640 profissionais na folha salarial de julho de 2017
# A Prefeitura de Campinas tem 2619 profissionais na folha salarial de agosto de 2017
# A Prefeitura de Campinas tem 2602 profissionais na folha salarial de setembro de 2017
# A Prefeitura de Campinas tem 2588 profissionais na folha salarial de outubro de 2017
# A Prefeitura de Campinas tem 2573 profissionais na folha salarial de novembro de 2017

# %%
#Contador do número de guardas municipais na Prefeitura de Campinas

import csv
planilha = open('SalariosCampinas_janeiro2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_fevereiro2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_marco2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_abril2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_maio2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_junho2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_julho2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_agosto2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_setembro2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

import csv
planilha = open('SalariosCampinas_outubro2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")

planilha = open('SalariosCampinas_novembro2017.csv')
busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial do mês")
# Out:
# A Prefeitura de Campinas tem 741 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 740 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 740 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 739 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 739 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 738 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 737 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 736 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 735 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 735 profissionais na folha salarial do mês
# A Prefeitura de Campinas tem 731 profissionais na folha salarial do mês

# %%
#Contador do número de servidores na Prefeitura de Campinas

import csv

busca_cargo = ["GUARDA MUNICIPAL", "GM 3"]
cargo_print = busca_cargo[0].title()

planilha = open('SalariosCampinas_janeiro2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de janeiro de 2017")

planilha = open('SalariosCampinas_fevereiro2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de fevereiro de 2017")

planilha = open('SalariosCampinas_marco2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de março de 2017")

planilha = open('SalariosCampinas_abril2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de abril de 2017")

planilha = open('SalariosCampinas_maio2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de maio de 2017")

planilha = open('SalariosCampinas_junho2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de junho de 2017")

planilha = open('SalariosCampinas_julho2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de julho de 2017")

planilha = open('SalariosCampinas_agosto2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de agosto de 2017")

planilha = open('SalariosCampinas_setembro2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de setembro de 2017")

planilha = open('SalariosCampinas_outubro2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de novembro de 2017")
# Out:
# A Prefeitura de Campinas tem 741 profissionais com o cargo de Guarda Municipal na folha salarial de janeiro de 2017
# A Prefeitura de Campinas tem 740 profissionais com o cargo de Guarda Municipal na folha salarial de fevereiro de 2017
# A Prefeitura de Campinas tem 740 profissionais com o cargo de Guarda Municipal na folha salarial de março de 2017
# A Prefeitura de Campinas tem 739 profissionais com o cargo de Guarda Municipal na folha salarial de abril de 2017
# A Prefeitura de Campinas tem 739 profissionais com o cargo de Guarda Municipal na folha salarial de maio de 2017
# A Prefeitura de Campinas tem 738 profissionais com o cargo de Guarda Municipal na folha salarial de junho de 2017
# A Prefeitura de Campinas tem 737 profissionais com o cargo de Guarda Municipal na folha salarial de julho de 2017
# A Prefeitura de Campinas tem 736 profissionais com o cargo de Guarda Municipal na folha salarial de agosto de 2017
# A Prefeitura de Campinas tem 735 profissionais com o cargo de Guarda Municipal na folha salarial de setembro de 2017
# A Prefeitura de Campinas tem 735 profissionais com o cargo de Guarda Municipal na folha salarial de outubro de 2017
# A Prefeitura de Campinas tem 731 profissionais com o cargo de Guarda Municipal na folha salarial de novembro de 2017
