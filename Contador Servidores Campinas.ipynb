# %% [markdown]
# # Monitor do número de servidores por secretaria na Prefeitura de Campinas
#
# A partir dos dados salariais fornecidos pela Prefeitura de Campinas em formato CSV, este monitor contabiliza mês a mês o número de servidores contratados por secretaria. Basta digitar a secretaria desejada com as primeiras letras em caixa alta ("Educação", "Direitos da Pessoa com Deficiência e Cidadania" etc) e o programa retorna os dados. Para mantê-lo atualizado basta, sempre que os novos arquivos forem diponibilizados pela administração municipal, inclui-los para análise e criar um novo bloco de código.

# %%
import csv

busca_secretaria = ["Cultura"]
busca_print = busca_secretaria[0].title()

planilha = open('SalariosCampinas_janeiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em janeiro de 2017")

planilha = open('SalariosCampinas_fevereiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em fevereiro de 2017")

planilha = open('SalariosCampinas_marco2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em março de 2017")

planilha = open('SalariosCampinas_abril2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em abril de 2017")

planilha = open('SalariosCampinas_maio2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em maio de 2017")

planilha = open('SalariosCampinas_junho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em junho de 2017")

planilha = open('SalariosCampinas_julho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em julho de 2017")

planilha = open('SalariosCampinas_agosto2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em agosto de 2017")

planilha = open('SalariosCampinas_setembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em setembro de 2017")

planilha = open('SalariosCampinas_outubro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_secretaria:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais na folha salarial da Secretaria de {busca_print} em novembro de 2017")
# Out:
# A Prefeitura de Campinas tem 316 profissionais na folha salarial da Secretaria de Cultura em janeiro de 2017
# A Prefeitura de Campinas tem 320 profissionais na folha salarial da Secretaria de Cultura em fevereiro de 2017
# A Prefeitura de Campinas tem 320 profissionais na folha salarial da Secretaria de Cultura em março de 2017
# A Prefeitura de Campinas tem 319 profissionais na folha salarial da Secretaria de Cultura em abril de 2017
# A Prefeitura de Campinas tem 315 profissionais na folha salarial da Secretaria de Cultura em maio de 2017
# A Prefeitura de Campinas tem 314 profissionais na folha salarial da Secretaria de Cultura em junho de 2017
# A Prefeitura de Campinas tem 310 profissionais na folha salarial da Secretaria de Cultura em julho de 2017
# A Prefeitura de Campinas tem 310 profissionais na folha salarial da Secretaria de Cultura em agosto de 2017
# A Prefeitura de Campinas tem 311 profissionais na folha salarial da Secretaria de Cultura em setembro de 2017
# A Prefeitura de Campinas tem 311 profissionais na folha salarial da Secretaria de Cultura em outubro de 2017
# A Prefeitura de Campinas tem 309 profissionais na folha salarial da Secretaria de Cultura em novembro de 2017

# %% [markdown]
# # Monitor do número de servidores por cargo na Prefeitura de Campinas
#
# A partir dos dados salariais fornecidos pela Prefeitura de Campinas em formato CSV, este monitor contabiliza mês a mês o número de servidores contratados por cargo. Basta digitar o cargo desejad todo em caixa alta ("GUARDA MUNICIPAL", "ASSISTENTE SOCIAL" etc) e o programa retorna os dados. Para mantê-lo atualizado basta, sempre que os novos arquivos forem diponibilizados pela administração municipal, inclui-los para análise e criar um novo bloco de código.

# %%
#Monitor do número de servidores da Prefeitura de Campinas por cargo

import csv

busca_cargo = ["PROFESSOR"]
cargo_print = busca_cargo[0].title()

planilha = open('SalariosCampinas_janeiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de janeiro de 2017")

planilha = open('SalariosCampinas_fevereiro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de fevereiro de 2017")

planilha = open('SalariosCampinas_marco2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de março de 2017")

planilha = open('SalariosCampinas_abril2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de abril de 2017")

planilha = open('SalariosCampinas_maio2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de maio de 2017")

planilha = open('SalariosCampinas_junho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de junho de 2017")

planilha = open('SalariosCampinas_julho2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de julho de 2017")

planilha = open('SalariosCampinas_agosto2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de agosto de 2017")

planilha = open('SalariosCampinas_setembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de setembro de 2017")

planilha = open('SalariosCampinas_outubro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de outubro de 2017")

planilha = open('SalariosCampinas_novembro2017.csv', encoding='utf-8')
cargo_encontrado = {}
contador_cargo = 0
for linha in planilha:
    for palavra in busca_cargo:
        if palavra in linha:
            contador_cargo = contador_cargo + 1
    cargo_encontrado[palavra] = contador_cargo
print(f"A Prefeitura de Campinas tem {contador_cargo} profissionais com o cargo de {cargo_print} na folha salarial de novembro de 2017")
# Out:
# A Prefeitura de Campinas tem 2555 profissionais com o cargo de Professor na folha salarial de janeiro de 2017
# A Prefeitura de Campinas tem 2539 profissionais com o cargo de Professor na folha salarial de fevereiro de 2017
# A Prefeitura de Campinas tem 2521 profissionais com o cargo de Professor na folha salarial de março de 2017
# A Prefeitura de Campinas tem 2505 profissionais com o cargo de Professor na folha salarial de abril de 2017
# A Prefeitura de Campinas tem 2489 profissionais com o cargo de Professor na folha salarial de maio de 2017
# A Prefeitura de Campinas tem 2469 profissionais com o cargo de Professor na folha salarial de junho de 2017
# A Prefeitura de Campinas tem 2450 profissionais com o cargo de Professor na folha salarial de julho de 2017
# A Prefeitura de Campinas tem 2431 profissionais com o cargo de Professor na folha salarial de agosto de 2017
# A Prefeitura de Campinas tem 2414 profissionais com o cargo de Professor na folha salarial de setembro de 2017
# A Prefeitura de Campinas tem 2400 profissionais com o cargo de Professor na folha salarial de outubro de 2017
# A Prefeitura de Campinas tem 2386 profissionais com o cargo de Professor na folha salarial de novembro de 2017

# %% [markdown]
# # Monitor do total de servidores na Prefeitura de Campinas
#
# Em construção.

# %%
arquivo = open("SalariosCampinas_janeiro2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de janeiro de 2017')

arquivo = open("SalariosCampinas_fevereiro2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de fevereiro de 2017')

arquivo = open("SalariosCampinas_marco2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de março de 2017')

arquivo = open("SalariosCampinas_abril2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de abril de 2017')

arquivo = open("SalariosCampinas_maio2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de maio de 2017')

arquivo = open("SalariosCampinas_junho2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de junho de 2017')

arquivo = open("SalariosCampinas_julho2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de julho de 2017')

arquivo = open("SalariosCampinas_agosto2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de agosto de 2017')

arquivo = open("SalariosCampinas_setembro2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de setembro de 2017')

arquivo = open("SalariosCampinas_outubro2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de outubro de 2017')

arquivo = open("SalariosCampinas_novembro2017.csv")
numero_linhas = len(arquivo.readlines())
print (f'A Prefeitura de Campinas tem aproximadamente {numero_linhas} servidores na folha salarial de novembro de 2017')
# Out:
# A Prefeitura de Campinas tem 5792 profissionais com o cargo de Educação na folha salarial de janeiro de 2017
# A Prefeitura de Campinas tem 5780 profissionais com o cargo de Educação na folha salarial de fevereiro de 2017
# A Prefeitura de Campinas tem 5814 profissionais com o cargo de Educação na folha salarial de março de 2017
# A Prefeitura de Campinas tem 5803 profissionais com o cargo de Educação na folha salarial de abril de 2017
# A Prefeitura de Campinas tem 5800 profissionais com o cargo de Educação na folha salarial de maio de 2017
# A Prefeitura de Campinas tem 5771 profissionais com o cargo de Educação na folha salarial de junho de 2017
# A Prefeitura de Campinas tem 5706 profissionais com o cargo de Educação na folha salarial de julho de 2017
# A Prefeitura de Campinas tem 5651 profissionais com o cargo de Educação na folha salarial de agosto de 2017
# A Prefeitura de Campinas tem 5542 profissionais com o cargo de Educação na folha salarial de setembro de 2017
# A Prefeitura de Campinas tem 5502 profissionais com o cargo de Educação na folha salarial de outubro de 2017
# A Prefeitura de Campinas tem 5472 profissionais com o cargo de Educação na folha salarial de novembro de 2017
